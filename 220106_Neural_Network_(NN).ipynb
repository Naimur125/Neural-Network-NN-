# %% [markdown]
# <a href="https://colab.research.google.com/github/Naimur125/Neural-Network-NN-/blob/main/220106_Neural_Network_(NN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
